# %% [markdown]
# # 数据分析实战

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import pandas_datareader as pdr
from pandas import Series, DataFrame
from datetime import datetime

# %% [markdown]
# ### 1

# %%
start = datetime(2015, 9, 20)
alibaba = pdr.get_data_yahoo('BABA', start=start)
amazon = pdr.get_data_yahoo('AMZN', start=start)

# %%
alibaba
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2015-09-21   66.400002   62.959999   65.379997   63.900002  22355100
# 2015-09-22   63.270000   61.580002   62.939999   61.900002  14897900
# 2015-09-23   62.299999   59.680000   61.959999   60.000000  22684600
# 2015-09-24   60.340000   58.209999   59.419998   59.919998  20645700
# 2015-09-25   60.840000   58.919998   60.630001   59.240002  17009100
# ...                ...         ...         ...         ...       ...
# 2019-12-26  216.990005  214.330002  214.649994  216.380005   6907100
# 2019-12-27  218.110001  215.169998  217.990005  215.470001  11674200
# 2019-12-30  215.779999  211.759995  215.779999  212.910004   8732600
# 2019-12-31  213.639999  210.729996  212.000000  212.100006   6773600
# 2020-01-02  219.979996  216.539993  216.600006  219.770004  15873500
#
#              Adj Close
# Date
# 2015-09-21   63.900002
# 2015-09-22   61.900002
# 2015-09-23   60.000000
# 2015-09-24   59.919998
# ...

# %%
amazon
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2015-09-21   549.780029   539.590027   544.330017   548.390015  3283300
# 2015-09-22   543.549988   532.659973   539.710022   538.400024  3841700
# 2015-09-23   541.210022   534.000000   538.299988   536.070007  2237600
# 2015-09-24   534.559998   522.869995   530.549988   533.750000  3501000
# 2015-09-25   542.799988   521.400024   542.570007   524.250000  4031000
# ...                 ...          ...          ...          ...      ...
# 2019-12-26  1870.459961  1799.500000  1801.010010  1868.770020  6005400
# 2019-12-27  1901.400024  1866.010010  1882.920044  1869.800049  6186600
# 2019-12-30  1884.000000  1840.619995  1874.000000  1846.890015  3674700
# 2019-12-31  1853.260010  1832.229980  1842.000000  1847.839966  2506500
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
#
#               Adj Close
# Date
# 2015-09-21   548.390015
# 2015-09-22   538.400024
# ...

# %% [markdown]
# ### 2

# %%
alibaba.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-12-26  216.990005  214.330002  214.649994  216.380005   6907100
# 2019-12-27  218.110001  215.169998  217.990005  215.470001  11674200
# 2019-12-30  215.779999  211.759995  215.779999  212.910004   8732600
# 2019-12-31  213.639999  210.729996  212.000000  212.100006   6773600
# 2020-01-02  219.979996  216.539993  216.600006  219.770004  15873500
#
#              Adj Close
# Date
# 2019-12-26  216.380005
# 2019-12-27  215.470001
# 2019-12-30  212.910004
# 2019-12-31  212.100006
# 2020-01-02  219.770004

# %%
alibaba.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1079.000000  1079.000000  1079.000000  1079.000000  1.079000e+03
# mean    141.486001   138.137363   139.931500   139.847386  1.675926e+07
# std      45.223313    44.260756    44.819334    44.751593  9.309487e+06
# min      58.650002    57.200001    57.299999    57.389999  3.775300e+06
# 25%      96.390003    94.145000    95.469997    95.355000  1.089285e+07
# 50%     156.169998   151.839996   154.639999   154.149994  1.474200e+07
# 75%     180.144997   176.215004   178.429993   178.260002  1.998170e+07
# max     219.979996   216.539993   217.990005   219.770004  9.791410e+07
#
#          Adj Close
# count  1079.000000
# mean    139.847386
# std      44.751593
# min      57.389999
# 25%      95.355000
# 50%     154.149994
# 75%     178.260002
# max     219.770004

# %% [markdown]
# ### 3、某股票历史趋势分析

# %%
sn.set()

# %% [markdown]
# #### 3.1

# %%
alibaba['Adj Close'].plot(legend=True, grid=True, style='r-', label='Alibaba')
amazon['Adj Close'].plot(legend=True, grid=True, style='b-', label='Amazon')
plt.show()

# %%
alibaba['Volume'].plot(legend=True, grid=True, style='r-')

# %% [markdown]
# #### 3.2

# %%
alibaba_1 = alibaba.copy()

# %%
alibaba_1.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002

# %%
alibaba_1['High-Low'] = alibaba_1['High'] - alibaba_1['Low']

# %%
alibaba_1.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002
#
#             High-Low
# Date
# 2015-09-21  3.440002
# 2015-09-22  1.689999
# 2015-09-23  2.619999
# 2015-09-24  2.130001
# 2015-09-25  1.920002

# %%
alibaba_1['High-Low'].plot(style='g-')
plt.show()

# %% [markdown]
# #### 3.3

# %%
alibaba_2 = alibaba.copy()

# %%
alibaba_2.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002

# %%
alibaba_2['Daily Return'] = alibaba_2['Adj Close'].pct_change()

# %%
alibaba_2.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002
#
#             Daily Return
# Date
# 2015-09-21           NaN
# 2015-09-22     -0.031299
# 2015-09-23     -0.030695
# 2015-09-24     -0.001333
# 2015-09-25     -0.011348

# %%
alibaba_2['Daily Return'].plot(figsize=(200, 4), style='r--', marker='o')
plt.show()

# %%
alibaba_2['Daily Return'].plot(kind='hist')
plt.show()

# %%
sn.distplot(alibaba_2['Daily Return'].dropna(), bins=100, color='red')

# %% [markdown]
# ### 4、某股票风险分析

# %% [markdown]
# #### 4.1

# %%
usa_tech_company = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB']

# %%
start=datetime(2019,1,1)

# %%
usa_tech_company_df = pdr.get_data_yahoo(usa_tech_company, start=start)['Adj Close']

# %%
usa_tech_company_df
# Out:
# Symbols           AAPL         GOOG        MSFT         AMZN          FB
# Date
# 2018-12-31  155.405045  1035.609985  100.090057  1501.969971  131.089996
# 2019-01-02  155.582367  1045.849976   99.646614  1539.130005  135.679993
# 2019-01-03  140.085220  1016.059998   95.980820  1500.280029  131.740005
# 2019-01-04  146.065353  1070.709961  100.444817  1575.390015  137.949997
# 2019-01-07  145.740265  1068.390015  100.572922  1629.510010  138.050003
# ...                ...          ...         ...          ...         ...
# 2019-12-26  289.910004  1360.400024  158.669998  1868.770020  207.789993
# 2019-12-27  289.799988  1351.890015  158.960007  1869.800049  208.100006
# 2019-12-30  291.519989  1336.140015  157.589996  1846.890015  204.410004
# 2019-12-31  293.649994  1337.020020  157.699997  1847.839966  205.250000
# 2020-01-02  300.350006  1367.369995  160.619995  1898.010010  209.779999
#
# [254 rows x 5 columns]

# %% [markdown]
# #### 4.2

# %%
daily_return_df1 = usa_tech_company_df.pct_change()

# %%
daily_return_df1
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN        FB
# Date
# 2018-12-31       NaN       NaN       NaN       NaN       NaN
# 2019-01-02  0.001141  0.009888 -0.004430  0.024741  0.035014
# 2019-01-03 -0.099607 -0.028484 -0.036788 -0.025242 -0.029039
# 2019-01-04  0.042689  0.053786  0.046509  0.050064  0.047138
# 2019-01-07 -0.002226 -0.002167  0.001275  0.034353  0.000725
# ...              ...       ...       ...       ...       ...
# 2019-12-26  0.019840  0.012534  0.008197  0.044467  0.013017
# 2019-12-27 -0.000379 -0.006256  0.001828  0.000551  0.001492
# 2019-12-30  0.005935 -0.011650 -0.008619 -0.012253 -0.017732
# 2019-12-31  0.007307  0.000659  0.000698  0.000514  0.004109
# 2020-01-02  0.022816  0.022700  0.018516  0.027151  0.022071
#
# [254 rows x 5 columns]

# %%
daily_return_df2 = daily_return_df.dropna()

# %%
daily_return_df2
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN        FB
# Date
# 2019-01-02  0.001141  0.009888 -0.004430  0.024741  0.035014
# 2019-01-03 -0.099607 -0.028484 -0.036788 -0.025242 -0.029039
# 2019-01-04  0.042689  0.053786  0.046509  0.050064  0.047138
# 2019-01-07 -0.002226 -0.002167  0.001275  0.034353  0.000725
# 2019-01-08  0.019063  0.007385  0.007251  0.016612  0.032452
# ...              ...       ...       ...       ...       ...
# 2019-12-26  0.019840  0.012534  0.008197  0.044467  0.013017
# 2019-12-27 -0.000379 -0.006256  0.001828  0.000551  0.001492
# 2019-12-30  0.005935 -0.011650 -0.008619 -0.012253 -0.017732
# 2019-12-31  0.007307  0.000659  0.000698  0.000514  0.004109
# 2020-01-02  0.022816  0.022700  0.018516  0.027151  0.022071
#
# [253 rows x 5 columns]

# %%
sn.set()
usa_tech_company_df.plot(legend=True)
plt.show()

# %% [markdown]
# #### 4.3

# %%
sn.set()

# %%
sn.jointplot('GOOG', 'GOOG', daily_return_df2, kind='scatter')

# %%
sn.jointplot('AMZN', 'GOOG', daily_return_df2, kind='scatter')

# %%
sn.jointplot('GOOG', 'AMZN', daily_return_df2, kind='scatter')

# %% [markdown]
# #### 4.4

# %%
sn.pairplot(daily_return_df2)
