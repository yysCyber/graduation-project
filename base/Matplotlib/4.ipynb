# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %% [markdown]
# ### 1

# %%
df1 = DataFrame(np.random.randint(1, 11, 40).reshape(10, 4), columns=['A', 'B', 'C', 'D'])
df1
# Out:
#    A   B  C   D
# 0  9  10  3   6
# 1  4   3  1  10
# 2  3   3  8   2
# 3  8  10  3   8
# 4  4   7  3   3
# 5  1   7  4   3
# 6  5   2  2  10
# 7  5   3  6   6
# 8  6   2  1   9
# 9  8   7  3   9

# %%
df1.plot()
plt.show()

# %% [markdown]
# ### 2

# %%
df2 = DataFrame(np.random.randint(1, 11, 40).reshape(10, 4), columns=['A', 'B', 'C', 'D'])
df2
# Out:
#     A   B  C   D
# 0   5   3  4   8
# 1   3   4  3   4
# 2   6  10  7   7
# 3   1   8  1   6
# 4   7   3  8   3
# 5   1   9  5  10
# 6  10   5  8  10
# 7   2   3  2   7
# 8   9   2  7   9
# 9   8  10  9   1

# %%
df2.plot(kind='bar')
plt.show()

# %% [markdown]
# ### 3

# %%
df3 = DataFrame(np.random.randint(1, 11, 40).reshape(10, 4), columns=['A', 'B', 'C', 'D'])
df3
# Out:
#     A  B   C   D
# 0   6  6   5   6
# 1   6  8   9   8
# 2   4  9   9   4
# 3   8  1  10   5
# 4  10  7  10   3
# 5   5  4   9  10
# 6   4  9   9   3
# 7   1  5   2   4
# 8   1  3   4   6
# 9   6  8   9   2

# %%
df3.plot(kind='barh')
plt.show()

# %% [markdown]
# ### 4

# %%
df4 = DataFrame(np.random.randint(1, 11, 40).reshape(10, 4), columns=['A', 'B', 'C', 'D'])
df4
# Out:
#    A   B  C   D
# 0  6   4  1   4
# 1  7   5  3   8
# 2  3   6  7   1
# 3  9   9  4   3
# 4  4   6  9   3
# 5  3   8  1  10
# 6  6   7  2  10
# 7  3  10  6   6
# 8  3   1  3   7
# 9  4   6  1   7

# %%
df4.plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# ### 5

# %%
df5 = DataFrame(np.random.randint(1, 11, 40).reshape(10, 4), columns=['A', 'B', 'C', 'D'])
df5
# Out:
#     A   B  C  D
# 0   4   9  3  1
# 1  10   1  4  4
# 2  10  10  1  2
# 3   8   4  1  1
# 4   8   3  1  8
# 5   7   5  7  1
# 6   2   9  7  7
# 7   9   4  6  6
# 8   7   6  1  7
# 9  10  10  9  2

# %%
df5.plot(kind='area')
plt.show()

# %% [markdown]
# ### 6

# %%
df6 = DataFrame(np.random.randint(1, 11, 100).reshape(10, 10), columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
df6
# Out:
#    A   B  C  D   E   F   G   H  I  J
# 0  2   6  1  1  10   6   2  10  3  1
# 1  3   9  7  9   5   3  10   3  2  6
# 2  9   7  9  4   6  10  10  10  8  9
# 3  3   9  2  7   6  10   3   9  4  1
# 4  8   8  1  7   1  10   1   1  5  9
# 5  9   7  5  9  10   9   3   2  8  1
# 6  1   1  7  6   6   7   8   4  9  5
# 7  2  10  8  9  10   6   5   3  9  2
# 8  3   1  2  9   2   8   4   7  6  8
# 9  8   5  9  9   7   3   5   7  7  9

# %%
df6.iloc[0]
# Out:
# A     2
# B     6
# C     1
# D     1
# E    10
# F     6
# G     2
# H    10
# I     3
# J     1
# Name: 0, dtype: int32

# %%
df6.iloc[0].plot()
plt.show()

# %% [markdown]
# ### 7

# %%
df7 = DataFrame(np.random.randint(1, 11, 100).reshape(10, 10), columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
df7
# Out:
#     A  B  C   D  E   F   G  H  I   J
# 0   2  2  2   2  1   4  10  7  3  10
# 1   4  2  7  10  5  10   1  9  6   2
# 2   1  9  4   3  4   8   8  1  8   4
# 3   4  8  4   9  6   9   9  9  8   2
# 4   9  3  8   1  2   3  10  8  1   2
# 5   6  7  2   2  1   4   5  4  7   8
# 6  10  4  8   7  6  10   9  3  9   3
# 7   4  9  6   2  6   9  10  4  7  10
# 8   5  7  7   6  5   9  10  4  2   7
# 9   7  7  8   7  4   3  10  3  1   5

# %%
for i in df7.index:
    df7.iloc[i].plot(label=str(i))
plt.legend()
plt.show()

# %% [markdown]
# ### 8

# %%
df8 = DataFrame(np.random.randint(1, 11, 100).reshape(10, 10), columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
df8
# Out:
#     A   B   C   D   E   F  G  H   I   J
# 0   4  10   2   2  10   9  5  7   9   5
# 1   5   5   3  10  10   5  2  6   4   1
# 2   5   7   9   7   9   6  2  8  10   5
# 3   1   5  10   2   1  10  9  2   2   2
# 4  10   7   5   5   9   2  2  7   9   9
# 5   4   9   7   3   9   2  2  9   6   4
# 6   7  10   6   6   1   6  2  5   9   4
# 7   5   3   4   5  10  10  7  2   2   9
# 8   8   7   9   5   2   9  5  2   4   6
# 9   6   5   8   3   2  10  3  7  10  10

# %%
df8['B'].plot(style='b-.')
plt.show()

# %% [markdown]
# ### 9

# %%
df9 = DataFrame(np.random.randint(1, 11, 100).reshape(10, 10), columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
df9
# Out:
#     A   B  C   D  E   F  G   H   I  J
# 0   4  10  8   6  9   5  9  10   1  5
# 1   1   4  2   2  3  10  8   9   7  6
# 2   7  10  6   8  4   7  9   4  10  3
# 3  10   4  1   5  4  10  6   3   5  2
# 4   6   1  1  10  8   3  4   9   5  5
# 5   3   7  5   7  8   1  2  10   4  2
# 6   8   3  2  10  2   8  7   5   5  5
# 7   3   7  2   4  4   8  4   6   3  3
# 8  10   1  1   2  1   4  5  10   5  8
# 9   9   7  8   6  5   1  6   3   5  1

# %%
for i in df8.columns:
    df8[i].plot(label=str(i))
plt.legend()
plt.show()

# %% [markdown]
# ### 10

# %%
df10 = DataFrame(np.random.randint(1, 11, 100).reshape(10, 10), columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
df10
# Out:
#     A   B   C   D   E   F  G   H  I   J
# 0   7   2   5   5   4  10  2   4  6  10
# 1   3  10  10  10   3   4  1  10  2   3
# 2   3   6   9   5   1   9  8   3  6   4
# 3  10   1   5   9   6   6  3   9  8   4
# 4   5   5   5   8   8   7  4   2  9   3
# 5   5  10   4   7   6   9  2   4  5  10
# 6   3   6   2   1   5   6  5   5  2   8
# 7  10  10   9   3   5   7  6   6  7   4
# 8   9   5   9   4   9   3  4   7  6   8
# 9   2   2   9   2  10   7  6  10  3   2

# %%
df10.plot(legend=True, grid=True)
plt.show()

# %%
df10.T.plot(legend=True, grid=True)
plt.show()
