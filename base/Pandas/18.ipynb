# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
import datetime

from pandas import Series, DataFrame
from datetime import datetime

# %% [markdown]
# ### 1

# %%
t1 = datetime(2020, 1, 1)
t1
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %% [markdown]
# ### 2

# %%
datetime_index = [datetime(2019, 10, 1), 
                  datetime(2019, 11, 1), 
                  datetime(2019, 12, 1), 
                  datetime(2020, 1, 1), 
                  datetime(2020, 2, 1)]

# %%
s1 = Series(np.random.randn(5), index=datetime_index)
s1
# Out:
# 2019-10-01    0.320655
# 2019-11-01    0.664199
# 2019-12-01   -2.462691
# 2020-01-01   -0.244561
# 2020-02-01   -0.803511
# dtype: float64

# %%
s1.index
# Out:
# DatetimeIndex(['2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
s1[0]
# Out:
# 0.3206551490930116

# %%
s1[4]
# Out:
# -0.8035105633985089

# %%
s1[datetime(2019, 10, 1)]
# Out:
# 0.3206551490930116

# %%
s1['2019-12-1']
# Out:
# -2.4626912988594594

# %%
s1['2019-12-01']
# Out:
# -2.4626912988594594

# %%
s1['20191201']
# Out:
# -2.4626912988594594

# %%
s1['2019-10']
# Out:
# 2019-10-01    0.320655
# dtype: float64

# %%
s1['2019']
# Out:
# 2019-10-01    0.320655
# 2019-11-01    0.664199
# 2019-12-01   -2.462691
# dtype: float64

# %%
s1['2020']
# Out:
# 2020-01-01   -0.244561
# 2020-02-01   -0.803511
# dtype: float64

# %% [markdown]
# ### 3

# %%
datetime_index_1 = pd.date_range(start='2020-01-01', periods=100)
datetime_index_1
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01',
#                '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17',
#                '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21',
# ...

# %% [markdown]
# ### 4

# %%
datetime_index_2 = pd.date_range(start='2020-01-01', periods=100, freq='W')
datetime_index_2
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-12', '2020-01-19', '2020-01-26',
#                '2020-02-02', '2020-02-09', '2020-02-16', '2020-02-23',
#                '2020-03-01', '2020-03-08', '2020-03-15', '2020-03-22',
#                '2020-03-29', '2020-04-05', '2020-04-12', '2020-04-19',
#                '2020-04-26', '2020-05-03', '2020-05-10', '2020-05-17',
#                '2020-05-24', '2020-05-31', '2020-06-07', '2020-06-14',
#                '2020-06-21', '2020-06-28', '2020-07-05', '2020-07-12',
#                '2020-07-19', '2020-07-26', '2020-08-02', '2020-08-09',
#                '2020-08-16', '2020-08-23', '2020-08-30', '2020-09-06',
#                '2020-09-13', '2020-09-20', '2020-09-27', '2020-10-04',
#                '2020-10-11', '2020-10-18', '2020-10-25', '2020-11-01',
#                '2020-11-08', '2020-11-15', '2020-11-22', '2020-11-29',
#                '2020-12-06', '2020-12-13', '2020-12-20', '2020-12-27',
# ...

# %% [markdown]
# ### 5

# %%
datetime_index_3 = pd.date_range(start='2020-01-01', periods=100, freq='W-MON')
datetime_index_3
# Out:
# DatetimeIndex(['2020-01-06', '2020-01-13', '2020-01-20', '2020-01-27',
#                '2020-02-03', '2020-02-10', '2020-02-17', '2020-02-24',
#                '2020-03-02', '2020-03-09', '2020-03-16', '2020-03-23',
#                '2020-03-30', '2020-04-06', '2020-04-13', '2020-04-20',
#                '2020-04-27', '2020-05-04', '2020-05-11', '2020-05-18',
#                '2020-05-25', '2020-06-01', '2020-06-08', '2020-06-15',
#                '2020-06-22', '2020-06-29', '2020-07-06', '2020-07-13',
#                '2020-07-20', '2020-07-27', '2020-08-03', '2020-08-10',
#                '2020-08-17', '2020-08-24', '2020-08-31', '2020-09-07',
#                '2020-09-14', '2020-09-21', '2020-09-28', '2020-10-05',
#                '2020-10-12', '2020-10-19', '2020-10-26', '2020-11-02',
#                '2020-11-09', '2020-11-16', '2020-11-23', '2020-11-30',
#                '2020-12-07', '2020-12-14', '2020-12-21', '2020-12-28',
# ...

# %% [markdown]
# ### 6

# %%
datetime_index_4 = pd.date_range(start='2020-01-01', periods=100, freq='H')
datetime_index_4
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                '2020-01-01 10:00:00', '2020-01-01 11:00:00',
#                '2020-01-01 12:00:00', '2020-01-01 13:00:00',
#                '2020-01-01 14:00:00', '2020-01-01 15:00:00',
#                '2020-01-01 16:00:00', '2020-01-01 17:00:00',
#                '2020-01-01 18:00:00', '2020-01-01 19:00:00',
#                '2020-01-01 20:00:00', '2020-01-01 21:00:00',
#                '2020-01-01 22:00:00', '2020-01-01 23:00:00',
#                '2020-01-02 00:00:00', '2020-01-02 01:00:00',
#                '2020-01-02 02:00:00', '2020-01-02 03:00:00',
#                '2020-01-02 04:00:00', '2020-01-02 05:00:00',
# ...

# %% [markdown]
# ### 7

# %%
datetime_index_5 = pd.date_range(start='2020-01-01', periods=100, freq='5H')
datetime_index_5
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 10:00:00', '2020-01-01 15:00:00',
#                '2020-01-01 20:00:00', '2020-01-02 01:00:00',
#                '2020-01-02 06:00:00', '2020-01-02 11:00:00',
#                '2020-01-02 16:00:00', '2020-01-02 21:00:00',
#                '2020-01-03 02:00:00', '2020-01-03 07:00:00',
#                '2020-01-03 12:00:00', '2020-01-03 17:00:00',
#                '2020-01-03 22:00:00', '2020-01-04 03:00:00',
#                '2020-01-04 08:00:00', '2020-01-04 13:00:00',
#                '2020-01-04 18:00:00', '2020-01-04 23:00:00',
#                '2020-01-05 04:00:00', '2020-01-05 09:00:00',
#                '2020-01-05 14:00:00', '2020-01-05 19:00:00',
#                '2020-01-06 00:00:00', '2020-01-06 05:00:00',
#                '2020-01-06 10:00:00', '2020-01-06 15:00:00',
#                '2020-01-06 20:00:00', '2020-01-07 01:00:00',
# ...

# %% [markdown]
# ### 8

# %%
s2 = Series(np.random.randn(100), index=pd.date_range(start='2020-01-01', freq='D', periods=100))
s2
# Out:
# 2020-01-01    0.210484
# 2020-01-02    0.410259
# 2020-01-03   -0.161761
# 2020-01-04   -0.324548
# 2020-01-05    0.757572
#                 ...
# 2020-04-05   -0.069693
# 2020-04-06   -2.607760
# 2020-04-07    0.067429
# 2020-04-08   -1.979880
# 2020-04-09    0.429122
# Freq: D, Length: 100, dtype: float64
