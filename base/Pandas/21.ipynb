# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### 1

# %%
df1 = pd.read_csv('datasource\\city_weather.csv')
df1
# Out:
#           date city  temperature  wind
# 0   03/01/2016   BJ            8     5
# 1   17/01/2016   BJ           12     2
# 2   31/01/2016   BJ           19     2
# 3   14/02/2016   BJ           -3     3
# 4   28/02/2016   BJ           19     2
# 5   13/03/2016   BJ            5     3
# 6   27/03/2016   SH           -4     4
# 7   10/04/2016   SH           19     3
# 8   24/04/2016   SH           20     3
# 9   08/05/2016   SH           17     3
# 10  22/05/2016   SH            4     2
# 11  05/06/2016   SH          -10     4
# 12  19/06/2016   SH            0     5
# 13  03/07/2016   SH           -9     5
# 14  17/07/2016   GZ           10     2
# 15  31/07/2016   GZ           -1     5
# 16  14/08/2016   GZ            1     5
# 17  28/08/2016   GZ           25     4
# 18  11/09/2016   SZ           20     1
# 19  25/09/2016   SZ          -10     4

# %% [markdown]
# ### 2

# %%
df1
# Out:
#           date city  temperature  wind
# 0   03/01/2016   BJ            8     5
# 1   17/01/2016   BJ           12     2
# 2   31/01/2016   BJ           19     2
# 3   14/02/2016   BJ           -3     3
# 4   28/02/2016   BJ           19     2
# 5   13/03/2016   BJ            5     3
# 6   27/03/2016   SH           -4     4
# 7   10/04/2016   SH           19     3
# 8   24/04/2016   SH           20     3
# 9   08/05/2016   SH           17     3
# 10  22/05/2016   SH            4     2
# 11  05/06/2016   SH          -10     4
# 12  19/06/2016   SH            0     5
# 13  03/07/2016   SH           -9     5
# 14  17/07/2016   GZ           10     2
# 15  31/07/2016   GZ           -1     5
# 16  14/08/2016   GZ            1     5
# 17  28/08/2016   GZ           25     4
# 18  11/09/2016   SZ           20     1
# 19  25/09/2016   SZ          -10     4

# %%
group_1 = df1.groupby(df1['city'])

# %%
type(group_1)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
group_1.groups
# Out:
# {'BJ': Int64Index([0, 1, 2, 3, 4, 5], dtype='int64'),
#  'GZ': Int64Index([14, 15, 16, 17], dtype='int64'),
#  'SH': Int64Index([6, 7, 8, 9, 10, 11, 12, 13], dtype='int64'),
#  'SZ': Int64Index([18, 19], dtype='int64')}

# %%
type(group_1.groups)
# Out:
# dict

# %%
df2 = group_1.get_group('BJ')
df2
# Out:
#          date city  temperature  wind
# 0  03/01/2016   BJ            8     5
# 1  17/01/2016   BJ           12     2
# 2  31/01/2016   BJ           19     2
# 3  14/02/2016   BJ           -3     3
# 4  28/02/2016   BJ           19     2
# 5  13/03/2016   BJ            5     3

# %%
df3 = group_1.get_group('SH')
df3
# Out:
#           date city  temperature  wind
# 6   27/03/2016   SH           -4     4
# 7   10/04/2016   SH           19     3
# 8   24/04/2016   SH           20     3
# 9   08/05/2016   SH           17     3
# 10  22/05/2016   SH            4     2
# 11  05/06/2016   SH          -10     4
# 12  19/06/2016   SH            0     5
# 13  03/07/2016   SH           -9     5

# %%
df2.mean()
# Out:
# temperature    10.000000
# wind            2.833333
# dtype: float64

# %% [markdown]
# ### 2

# %%
df3 = group_1.mean()
df3
# Out:
#       temperature      wind
# city
# BJ         10.000  2.833333
# GZ          8.750  4.000000
# SH          4.625  3.625000
# SZ          5.000  2.500000

# %%
df4 = group_1.max()
df4
# Out:
#             date  temperature  wind
# city
# BJ    31/01/2016           19     5
# GZ    31/07/2016           25     5
# SH    27/03/2016           20     5
# SZ    25/09/2016           20     4

# %%
df5 = group_1.min()
df5
# Out:
#             date  temperature  wind
# city
# BJ    03/01/2016           -3     2
# GZ    14/08/2016           -1     2
# SH    03/07/2016          -10     2
# SZ    11/09/2016          -10     1

# %% [markdown]
# ### 3

# %%
list(group_1)
# Out:
# [('BJ',          date city  temperature  wind
#   0  03/01/2016   BJ            8     5
#   1  17/01/2016   BJ           12     2
#   2  31/01/2016   BJ           19     2
#   3  14/02/2016   BJ           -3     3
#   4  28/02/2016   BJ           19     2
#   5  13/03/2016   BJ            5     3),
#  ('GZ',           date city  temperature  wind
#   14  17/07/2016   GZ           10     2
#   15  31/07/2016   GZ           -1     5
#   16  14/08/2016   GZ            1     5
#   17  28/08/2016   GZ           25     4),
#  ('SH',           date city  temperature  wind
#   6   27/03/2016   SH           -4     4
#   7   10/04/2016   SH           19     3
#   8   24/04/2016   SH           20     3
#   9   08/05/2016   SH           17     3
#   10  22/05/2016   SH            4     2
#   11  05/06/2016   SH          -10     4
#   12  19/06/2016   SH            0     5
#   13  03/07/2016   SH           -9     5),
#  ('SZ',           date city  temperature  wind
# ...

# %% [markdown]
# ### 4

# %%
dict(list(group_1))
# Out:
# {'BJ':          date city  temperature  wind
#  0  03/01/2016   BJ            8     5
#  1  17/01/2016   BJ           12     2
#  2  31/01/2016   BJ           19     2
#  3  14/02/2016   BJ           -3     3
#  4  28/02/2016   BJ           19     2
#  5  13/03/2016   BJ            5     3,
#  'GZ':           date city  temperature  wind
#  14  17/07/2016   GZ           10     2
#  15  31/07/2016   GZ           -1     5
#  16  14/08/2016   GZ            1     5
#  17  28/08/2016   GZ           25     4,
#  'SH':           date city  temperature  wind
#  6   27/03/2016   SH           -4     4
#  7   10/04/2016   SH           19     3
#  8   24/04/2016   SH           20     3
#  9   08/05/2016   SH           17     3
#  10  22/05/2016   SH            4     2
#  11  05/06/2016   SH          -10     4
#  12  19/06/2016   SH            0     5
#  13  03/07/2016   SH           -9     5,
#  'SZ':           date city  temperature  wind
#  18  11/09/2016   SZ           20     1
# ...

# %%
dict(list(group_1))['SZ']
# Out:
#           date city  temperature  wind
# 18  11/09/2016   SZ           20     1
# 19  25/09/2016   SZ          -10     4

# %% [markdown]
# ### 5

# %%
for tuple_name, tuple_df in group_1:
    print(tuple_name)
    print()
    print(tuple_df)
    print()
# Out:
# BJ
#
#          date city  temperature  wind
# 0  03/01/2016   BJ            8     5
# 1  17/01/2016   BJ           12     2
# 2  31/01/2016   BJ           19     2
# 3  14/02/2016   BJ           -3     3
# 4  28/02/2016   BJ           19     2
# 5  13/03/2016   BJ            5     3
#
# GZ
#
#           date city  temperature  wind
# 14  17/07/2016   GZ           10     2
# 15  31/07/2016   GZ           -1     5
# 16  14/08/2016   GZ            1     5
# 17  28/08/2016   GZ           25     4
#
# SH
#
#           date city  temperature  wind
# 6   27/03/2016   SH           -4     4
# 7   10/04/2016   SH           19     3
# 8   24/04/2016   SH           20     3
# 9   08/05/2016   SH           17     3
# 10  22/05/2016   SH            4     2
# 11  05/06/2016   SH          -10     4
# 12  19/06/2016   SH            0     5
# 13  03/07/2016   SH           -9     5
#
# SZ
#
#           date city  temperature  wind
# 18  11/09/2016   SZ           20     1
# ...
