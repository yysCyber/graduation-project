# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### 1

# %%
df1 = pd.read_clipboard()

# %%
df1
# Out:
#    Dec 2019  Dec 2018  Change Programming Language  Ratings Change.1
# 0         1         1     NaN                 Java  17.253%   +1.32%
# 1         2         2     NaN                    C  16.086%   +1.80%
# 2         3         3     NaN               Python  10.308%   +1.93%
# 3         4         4     NaN                  C++   6.196%   -1.37%
# 4         5         6  change                   C#   4.801%   +1.35%
# 5         6         5  change    Visual Basic .NET   4.743%   -2.38%
# 6         7         7     NaN           JavaScript   2.090%   -0.97%
# 7         8         8     NaN                  PHP   2.048%   -0.39%
# 8         9         9     NaN                  SQL   1.843%   -0.34%
# 9        10        14  change                Swift   1.490%   +0.27%

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 2

# %%
df1
# Out:
#    Dec 2019  Dec 2018  Change Programming Language  Ratings Change.1
# 0         1         1     NaN                 Java  17.253%   +1.32%
# 1         2         2     NaN                    C  16.086%   +1.80%
# 2         3         3     NaN               Python  10.308%   +1.93%
# 3         4         4     NaN                  C++   6.196%   -1.37%
# 4         5         6  change                   C#   4.801%   +1.35%
# 5         6         5  change    Visual Basic .NET   4.743%   -2.38%
# 6         7         7     NaN           JavaScript   2.090%   -0.97%
# 7         8         8     NaN                  PHP   2.048%   -0.39%
# 8         9         9     NaN                  SQL   1.843%   -0.34%
# 9        10        14  change                Swift   1.490%   +0.27%

# %%
df1.columns
# Out:
# Index(['Dec 2019', 'Dec 2018', 'Change', 'Programming Language', 'Ratings',
#        'Change.1'],
#       dtype='object')

# %%
type(df1.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ### 3

# %%
df1
# Out:
#    Dec 2019  Dec 2018  Change Programming Language  Ratings Change.1
# 0         1         1     NaN                 Java  17.253%   +1.32%
# 1         2         2     NaN                    C  16.086%   +1.80%
# 2         3         3     NaN               Python  10.308%   +1.93%
# 3         4         4     NaN                  C++   6.196%   -1.37%
# 4         5         6  change                   C#   4.801%   +1.35%
# 5         6         5  change    Visual Basic .NET   4.743%   -2.38%
# 6         7         7     NaN           JavaScript   2.090%   -0.97%
# 7         8         8     NaN                  PHP   2.048%   -0.39%
# 8         9         9     NaN                  SQL   1.843%   -0.34%
# 9        10        14  change                Swift   1.490%   +0.27%

# %%
df1['Programming Language']
# Out:
# 0                 Java
# 1                    C
# 2               Python
# 3                  C++
# 4                   C#
# 5    Visual Basic .NET
# 6           JavaScript
# 7                  PHP
# 8                  SQL
# 9                Swift
# Name: Programming Language, dtype: object

# %%
type(df1['Programming Language'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 4

# %%
df1
# Out:
#    Dec 2019  Dec 2018  Change Programming Language  Ratings Change.1
# 0         1         1     NaN                 Java  17.253%   +1.32%
# 1         2         2     NaN                    C  16.086%   +1.80%
# 2         3         3     NaN               Python  10.308%   +1.93%
# 3         4         4     NaN                  C++   6.196%   -1.37%
# 4         5         6  change                   C#   4.801%   +1.35%
# 5         6         5  change    Visual Basic .NET   4.743%   -2.38%
# 6         7         7     NaN           JavaScript   2.090%   -0.97%
# 7         8         8     NaN                  PHP   2.048%   -0.39%
# 8         9         9     NaN                  SQL   1.843%   -0.34%
# 9        10        14  change                Swift   1.490%   +0.27%

# %%
df2 = DataFrame(df1, columns=['Dec 2019', 'Programming Language'])

# %%
df2
# Out:
#    Dec 2019 Programming Language
# 0         1                 Java
# 1         2                    C
# 2         3               Python
# 3         4                  C++
# 4         5                   C#
# 5         6    Visual Basic .NET
# 6         7           JavaScript
# 7         8                  PHP
# 8         9                  SQL
# 9        10                Swift

# %% [markdown]
# ### 5

# %%
df1
# Out:
#    Dec 2019  Dec 2018  Change Programming Language  Ratings Change.1
# 0         1         1     NaN                 Java  17.253%   +1.32%
# 1         2         2     NaN                    C  16.086%   +1.80%
# 2         3         3     NaN               Python  10.308%   +1.93%
# 3         4         4     NaN                  C++   6.196%   -1.37%
# 4         5         6  change                   C#   4.801%   +1.35%
# 5         6         5  change    Visual Basic .NET   4.743%   -2.38%
# 6         7         7     NaN           JavaScript   2.090%   -0.97%
# 7         8         8     NaN                  PHP   2.048%   -0.39%
# 8         9         9     NaN                  SQL   1.843%   -0.34%
# 9        10        14  change                Swift   1.490%   +0.27%

# %%
df3 = DataFrame(df1, columns=['Dec 2019', 'Programming Language', 'Ratings', 'Unknow Column'])

# %%
df3
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
type(df3['Unknow Column'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 6

# %%
df3
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
df3['Unknow Column']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: Unknow Column, dtype: float64

# %%
df4 = DataFrame(df3, columns=['Dec 2019', 'Programming Language', 'Ratings', 'Unknow Column'])

# %%
df4
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
# Python 的 list 给列赋值
df4['Unknow Column'] = ['Oracle', np.nan, np.nan, np.nan, 'Microsoft', 'Microsoft', np.nan, np.nan, np.nan, np.nan]
df4
# Out:
#    Dec 2019 Programming Language  Ratings Unknow Column
# 0         1                 Java  17.253%        Oracle
# 1         2                    C  16.086%           NaN
# 2         3               Python  10.308%           NaN
# 3         4                  C++   6.196%           NaN
# 4         5                   C#   4.801%     Microsoft
# 5         6    Visual Basic .NET   4.743%     Microsoft
# 6         7           JavaScript   2.090%           NaN
# 7         8                  PHP   2.048%           NaN
# 8         9                  SQL   1.843%           NaN
# 9        10                Swift   1.490%           NaN

# %% [markdown]
# ### 7

# %%
df3
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
df5 = DataFrame(df3, columns=['Dec 2019', 'Programming Language', 'Ratings', 'Unknow Column'])
df5
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
# 使用 Pandas 的 Series 给列赋值
df5['Unknow Column'] = Series(['Oracle', np.nan, np.nan, np.nan, 'Microsoft', 'Microsoft', np.nan, np.nan, np.nan, np.nan])
df5
# Out:
#    Dec 2019 Programming Language  Ratings Unknow Column
# 0         1                 Java  17.253%        Oracle
# 1         2                    C  16.086%           NaN
# 2         3               Python  10.308%           NaN
# 3         4                  C++   6.196%           NaN
# 4         5                   C#   4.801%     Microsoft
# 5         6    Visual Basic .NET   4.743%     Microsoft
# 6         7           JavaScript   2.090%           NaN
# 7         8                  PHP   2.048%           NaN
# 8         9                  SQL   1.843%           NaN
# 9        10                Swift   1.490%           NaN

# %% [markdown]
# ### 8

# %%
df3
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
df6 = DataFrame(df3, columns=['Dec 2019', 'Programming Language', 'Ratings', 'Unknow Column'])
df6
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
# 使用 NumPy 的 Array 给列赋值
df6['Unknow Column'] = np.arange(10)
df6
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%              0
# 1         2                    C  16.086%              1
# 2         3               Python  10.308%              2
# 3         4                  C++   6.196%              3
# 4         5                   C#   4.801%              4
# 5         6    Visual Basic .NET   4.743%              5
# 6         7           JavaScript   2.090%              6
# 7         8                  PHP   2.048%              7
# 8         9                  SQL   1.843%              8
# 9        10                Swift   1.490%              9

# %% [markdown]
# ### 9

# %%
df3
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
df7 = DataFrame(df3, columns=['Dec 2019', 'Programming Language', 'Ratings', 'Unknow Column'])
df7
# Out:
#    Dec 2019 Programming Language  Ratings  Unknow Column
# 0         1                 Java  17.253%            NaN
# 1         2                    C  16.086%            NaN
# 2         3               Python  10.308%            NaN
# 3         4                  C++   6.196%            NaN
# 4         5                   C#   4.801%            NaN
# 5         6    Visual Basic .NET   4.743%            NaN
# 6         7           JavaScript   2.090%            NaN
# 7         8                  PHP   2.048%            NaN
# 8         9                  SQL   1.843%            NaN
# 9        10                Swift   1.490%            NaN

# %%
df7['Unknow Column'] = Series(['Oracle'], index=[0])
df7
# Out:
#    Dec 2019 Programming Language  Ratings Unknow Column
# 0         1                 Java  17.253%        Oracle
# 1         2                    C  16.086%           NaN
# 2         3               Python  10.308%           NaN
# 3         4                  C++   6.196%           NaN
# 4         5                   C#   4.801%           NaN
# 5         6    Visual Basic .NET   4.743%           NaN
# 6         7           JavaScript   2.090%           NaN
# 7         8                  PHP   2.048%           NaN
# 8         9                  SQL   1.843%           NaN
# 9        10                Swift   1.490%           NaN

# %%
df7['Unknow Column'] = Series(['Oracle', 'Microsoft', 'Microsoft'], index=[0, 4, 5])
df7
# Out:
#    Dec 2019 Programming Language  Ratings Unknow Column
# 0         1                 Java  17.253%        Oracle
# 1         2                    C  16.086%           NaN
# 2         3               Python  10.308%           NaN
# 3         4                  C++   6.196%           NaN
# 4         5                   C#   4.801%     Microsoft
# 5         6    Visual Basic .NET   4.743%     Microsoft
# 6         7           JavaScript   2.090%           NaN
# 7         8                  PHP   2.048%           NaN
# 8         9                  SQL   1.843%           NaN
# 9        10                Swift   1.490%           NaN
