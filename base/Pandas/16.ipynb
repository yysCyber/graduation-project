# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### 1

# %%
df = pd.read_csv('datasource\\apply_demo.csv')

# %%
df.head()
# Out:
#          time                                data
# 0  1473411962   Symbol: APPL Seqno: 0 Price: 1623
# 1  1473411962   Symbol: APPL Seqno: 0 Price: 1623
# 2  1473411963   Symbol: APPL Seqno: 0 Price: 1623
# 3  1473411963   Symbol: APPL Seqno: 0 Price: 1623
# 4  1473411963   Symbol: APPL Seqno: 1 Price: 1649

# %% [markdown]
# ### 2

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#          time                                data
# 0  1473411962   Symbol: APPL Seqno: 0 Price: 1623
# 1  1473411962   Symbol: APPL Seqno: 0 Price: 1623
# 2  1473411963   Symbol: APPL Seqno: 0 Price: 1623
# 3  1473411963   Symbol: APPL Seqno: 0 Price: 1623
# 4  1473411963   Symbol: APPL Seqno: 1 Price: 1649

# %%
df1['new_col'] = Series(['a'] * df1.size)

# %%
df1
# Out:
#             time                                  data new_col
# 0     1473411962     Symbol: APPL Seqno: 0 Price: 1623       a
# 1     1473411962     Symbol: APPL Seqno: 0 Price: 1623       a
# 2     1473411963     Symbol: APPL Seqno: 0 Price: 1623       a
# 3     1473411963     Symbol: APPL Seqno: 0 Price: 1623       a
# 4     1473411963     Symbol: APPL Seqno: 1 Price: 1649       a
# ...          ...                                   ...     ...
# 3984  1473412961   Symbol: APPL Seqno: 998 Price: 1680       a
# 3985  1473412961   Symbol: APPL Seqno: 999 Price: 1509       a
# 3986  1473412961   Symbol: APPL Seqno: 999 Price: 1509       a
# 3987  1473412961   Symbol: APPL Seqno: 999 Price: 1509       a
# 3988  1473412962   Symbol: APPL Seqno: 999 Price: 1509       a
#
# [3989 rows x 3 columns]

# %%
df1['new_col'] = df1['new_col'].apply(str.upper)

# %%
df1
# Out:
#             time                                  data new_col
# 0     1473411962     Symbol: APPL Seqno: 0 Price: 1623       A
# 1     1473411962     Symbol: APPL Seqno: 0 Price: 1623       A
# 2     1473411963     Symbol: APPL Seqno: 0 Price: 1623       A
# 3     1473411963     Symbol: APPL Seqno: 0 Price: 1623       A
# 4     1473411963     Symbol: APPL Seqno: 1 Price: 1649       A
# ...          ...                                   ...     ...
# 3984  1473412961   Symbol: APPL Seqno: 998 Price: 1680       A
# 3985  1473412961   Symbol: APPL Seqno: 999 Price: 1509       A
# 3986  1473412961   Symbol: APPL Seqno: 999 Price: 1509       A
# 3987  1473412961   Symbol: APPL Seqno: 999 Price: 1509       A
# 3988  1473412962   Symbol: APPL Seqno: 999 Price: 1509       A
#
# [3989 rows x 3 columns]

# %% [markdown]
# ### 3

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#          time                                data
# 0  1473411962   Symbol: APPL Seqno: 0 Price: 1623
# 1  1473411962   Symbol: APPL Seqno: 0 Price: 1623
# 2  1473411963   Symbol: APPL Seqno: 0 Price: 1623
# 3  1473411963   Symbol: APPL Seqno: 0 Price: 1623
# 4  1473411963   Symbol: APPL Seqno: 1 Price: 1649

# %%
df2['data'][0].split()
# Out:
# ['Symbol:', 'APPL', 'Seqno:', '0', 'Price:', '1623']

# %%
def split_data(data):
    items = data.split()
    return Series([items[1], items[3], items[5]])

# %%
df2_temp = df2['data'].apply(split_data)

# %%
df2_temp
# Out:
#          0    1     2
# 0     APPL    0  1623
# 1     APPL    0  1623
# 2     APPL    0  1623
# 3     APPL    0  1623
# 4     APPL    1  1649
# ...    ...  ...   ...
# 3984  APPL  998  1680
# 3985  APPL  999  1509
# 3986  APPL  999  1509
# 3987  APPL  999  1509
# 3988  APPL  999  1509
#
# [3989 rows x 3 columns]

# %%
df2_temp = df2_temp.rename(columns={0: 'symbol', 1: 'seqno', 2: 'price'})

# %%
df2_temp
# Out:
#      symbol seqno price
# 0      APPL     0  1623
# 1      APPL     0  1623
# 2      APPL     0  1623
# 3      APPL     0  1623
# 4      APPL     1  1649
# ...     ...   ...   ...
# 3984   APPL   998  1680
# 3985   APPL   999  1509
# 3986   APPL   999  1509
# 3987   APPL   999  1509
# 3988   APPL   999  1509
#
# [3989 rows x 3 columns]

# %%
df3 = df2.combine_first(df2_temp).drop(columns='data')

# %%
df3 = df3.reindex(columns=['time', 'symbol', 'seqno', 'price'])

# %%
df3
# Out:
#             time symbol  seqno   price
# 0     1473411962   APPL    0.0  1623.0
# 1     1473411962   APPL    0.0  1623.0
# 2     1473411963   APPL    0.0  1623.0
# 3     1473411963   APPL    0.0  1623.0
# 4     1473411963   APPL    1.0  1649.0
# ...          ...    ...    ...     ...
# 3984  1473412961   APPL  998.0  1680.0
# 3985  1473412961   APPL  999.0  1509.0
# 3986  1473412961   APPL  999.0  1509.0
# 3987  1473412961   APPL  999.0  1509.0
# 3988  1473412962   APPL  999.0  1509.0
#
# [3989 rows x 4 columns]

# %%
df3.to_csv('datasource\\duplicate_demo.csv', index=False)
